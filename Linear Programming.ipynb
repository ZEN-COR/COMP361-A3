# %% [markdown]
# ### Linear Programming

# %%
# (LP) Problem

# %%
# Optimal Solution
    # Pivot row
    # New Variables
        # (BV) Basic 
        # (NBV) Non Basic Variable

# %%
# Simplex Algorithm
def simplex_alg():
"""
"""
    #max =

# %% [markdown]
# ### References
# - Assignment 3 Brief: COMP361_A3_2026.pdf
# - COMP361/WK9/linear-programming.pdf
